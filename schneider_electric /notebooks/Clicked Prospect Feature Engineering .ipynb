# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date,datetime,timedelta

# %%
prospect_engagements=pd.read_csv('../datasets/result_datasets/Email_Engagement_Aggregated/unique_prospect_engagements.csv')

# %%
unique_clicked_engagements=prospect_engagements[(prospect_engagements['status']=='EMAIL_CLICKED')]

# %%
prospect_engagements.shape
# Out:
# (5663590, 30)

# %%
prospect_engagements['status'].value_counts()
# Out:
# status
# EMAIL_SENT        4246426
# EMAIL_NOT_SENT    1141472
# BOUNCED            129335
# EMAIL_OPENED        39695
# EMAIL_CLICKED       29931
# SCHEDULED           26650
# ERROR                2073
# UNSUBSCRIBED         1866
# RESPONDED             174
# -                       2
# Name: count, dtype: int64

# %%
unique_clicked_engagements.shape
# Out:
# (29931, 30)

# %%
unique_clicked_engagements['derived_mail'].nunique()
# Out:
# 9521

# %%
unique_clicked_engagements.duplicated(subset=['FirstName', 'CompanyName', 'mail', 'Email', 'CTA', 'Domain', 'ID',
        'date', 'raw_status',]).sum()
# Out:
# 0

# %%
unique_clicked_engagements['derived_mail'].value_counts()
# Out:
# derived_mail
# anahi.c@byd.com                    66
# mark_ard@ahm.honda.com             36
# tark_martin@ahm.honda.com          36
# harminder_pooni@ahm.honda.com      30
# edgar_morales@honda.com            30
#                                    ..
# nicholas.holley@duke-energy.com     1
# eveline.lim@aecom.com               1
# nicholas.lombardo@lmco.com          1
# nicholas.moran@analog.com           1
# a-holley@ti.com                     1
# Name: count, Length: 9521, dtype: int64

# %%
prospect_engagements['status_time_utc']=pd.to_datetime(prospect_engagements['status_time_utc'],utc=True)

# %%
unique_clicked_engagements['status_time_utc']=pd.to_datetime(unique_clicked_engagements['status_time_utc'],utc=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\3369448953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_clicked_engagements['status_time_utc']=pd.to_datetime(unique_clicked_engagements['status_time_utc'],utc=True)

# %%
unique_clicked_engagements.drop(columns=['Unnamed: 0'],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\926835702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_clicked_engagements.drop(columns=['Unnamed: 0'],inplace=True)

# %%
unique_clicked_engagements.sort_values(by=['derived_mail','status_time_utc'])[['derived_mail','status_time_utc','status']].head(20)
# Out:
#                        derived_mail           status_time_utc         status
# 812                 a-holley@ti.com 2024-07-21 10:21:00+00:00  EMAIL_CLICKED
# 1105                a-smith3@ti.com 2024-06-19 00:49:00+00:00  EMAIL_CLICKED
# 2296            a.danielson@aps.com 2024-01-26 14:47:00+00:00  EMAIL_CLICKED
# 2645          a.freitas@samsung.com 2024-08-06 16:19:00+00:00  EMAIL_CLICKED
# 2668          a.freitas@samsung.com 2024-09-02 17:06:00+00:00  EMAIL_CLICKED
# 3540            a.khani@samsung.com 2024-08-06 16:19:00+00:00  EMAIL_CLICKED
# 3868           a.kurian@samsung.com 2024-09-02 17:09:00+00:00  EMAIL_CLICKED
# 5405          a.singhal@samsung.com 2024-09-02 17:09:00+00:00  EMAIL_CLICKED
# 5700     a.wilcox@nexteraenergy.com 2024-12-26 12:21:00+00:00  EMAIL_CLICKED
# 5701     a.wilcox@nexteraenergy.com 2024-12-26 12:21:00+00:00  EMAIL_CLICKED
# 5720     a.wilcox@nexteraenergy.com 2025-01-14 20:28:00+00:00  EMAIL_CLICKED
# 5726     a.wilcox@nexteraenergy.com 2025-01-22 04:35:00+00:00  EMAIL_CLICKED
# 8419          aalcantara@rivian.com 2024-08-16 13:37:00+00:00  EMAIL_CLICKED
# 9687               aamin@rivian.com 2024-08-13 01:33:00+00:00  EMAIL_CLICKED
# 9688               aamin@rivian.com 2024-08-13 01:33:00+00:00  EMAIL_CLICKED
# 9775    aamir.aziz@thermofisher.com 2024-04-24 02:09:00+00:00  EMAIL_CLICKED
# 9776    aamir.aziz@thermofisher.com 2024-04-24 02:09:00+00:00  EMAIL_CLICKED
# 9879            aamir.hamid@amd.com 2024-08-06 17:46:00+00:00  EMAIL_CLICKED
# 9880            aamir.hamid@amd.com 2024-08-07 23:39:00+00:00  EMAIL_CLICKED
# 9909  aamir.khizar@nationalgrid.com 2024-01-20 18:18:00+00:00  EMAIL_CLICKED

# %%
pd.options.display.max_columns=None
pd.options.display.max_info_columns=1000

# %%
clicked_prospects_emails=unique_clicked_engagements.groupby('derived_mail',as_index=False).first()

# %%
clicked_prospects_emails.shape
# Out:
# (9521, 29)

# %%
clicked_prospects_emails[['derived_mail','status_time_utc','status']].head(20)
# Out:
#                      derived_mail           status_time_utc         status
# 0                 a-holley@ti.com 2024-07-21 10:21:00+00:00  EMAIL_CLICKED
# 1                 a-smith3@ti.com 2024-06-19 00:49:00+00:00  EMAIL_CLICKED
# 2             a.danielson@aps.com 2024-01-26 14:47:00+00:00  EMAIL_CLICKED
# 3           a.freitas@samsung.com 2024-08-06 16:19:00+00:00  EMAIL_CLICKED
# 4             a.khani@samsung.com 2024-08-06 16:19:00+00:00  EMAIL_CLICKED
# 5            a.kurian@samsung.com 2024-09-02 17:09:00+00:00  EMAIL_CLICKED
# 6           a.singhal@samsung.com 2024-09-02 17:09:00+00:00  EMAIL_CLICKED
# 7      a.wilcox@nexteraenergy.com 2024-12-26 12:21:00+00:00  EMAIL_CLICKED
# 8           aalcantara@rivian.com 2024-08-16 13:37:00+00:00  EMAIL_CLICKED
# 9                aamin@rivian.com 2024-08-13 01:33:00+00:00  EMAIL_CLICKED
# 10    aamir.aziz@thermofisher.com 2024-04-24 02:09:00+00:00  EMAIL_CLICKED
# 11            aamir.hamid@amd.com 2024-08-06 17:46:00+00:00  EMAIL_CLICKED
# 12  aamir.khizar@nationalgrid.com 2024-01-20 18:18:00+00:00  EMAIL_CLICKED
# 13          aamos@duke-energy.com 2023-12-13 15:00:00+00:00  EMAIL_CLICKED
# 14        aarnott@charlottenc.gov 2024-10-30 16:13:00+00:00  EMAIL_CLICKED
# 15     aaron.bills@xcelenergy.com 2024-11-20 16:17:00+00:00  EMAIL_CLICKED
# 16  aaron.blood@nexteraenergy.com 2025-01-14 21:16:00+00:00  EMAIL_CLICKED
# 17    aaron.chladil@xenuclear.com 2024-11-06 15:16:00+00:00  EMAIL_CLICKED
# 18        aaron.colchado@lmco.com 2024-09-27 20:20:00+00:00  EMAIL_CLICKED
# 19     aaron.dale@duke-energy.com 2023-12-14 18:51:00+00:00  EMAIL_CLICKED

# %%
clicked_prospects_emails=clicked_prospects_emails[['derived_mail','status_time_utc','status']]

# %%
clicked_prospects_emails.columns=['derived_mail','email_clicked_time','status']

# %%
prospects_firmo_data=pd.read_csv('../datasets/result_datasets/firmo_data/unique_prospect_firmo_data.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\3404426394.py:1: DtypeWarning: Columns (7,10,13,14,15,22,26,27,28,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   prospects_firmo_data=pd.read_csv('../datasets/result_datasets/firmo_data/unique_prospect_firmo_data.csv')

# %%
prospects_firmo_data.shape
# Out:
# (157517, 34)

# %%
prospects_firmo_data.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'First Name', 'Middle Name', 'Last Name',
#        'Title', 'Level', 'Seniority', 'Department', 'Email ID', 'Email 1',
#        'Contact_City', 'Contact_State', 'Contact City', 'Contact State',
#        'Contact Country', 'Country', 'Website', 'Company City',
#        'Company State', 'Company Country', 'Industry', 'Sub Industry',
#        'Revenue', 'Revenue Range', 'EMP Range', 'Company Annual Revenue',
#        'Company Industry', 'Company Staff Count Range', 'Company Staff Count',
#        'Contact Linkedin URL', 'Contact LI Profile URL', 'source', 'Email'],
#       dtype='object')

# %%
prospects_firmo_data['Email']= prospects_firmo_data['Email 1'].fillna(prospects_firmo_data['Email ID'])

# %%
prospects_firmo_data['Level']= prospects_firmo_data['Level'].fillna(prospects_firmo_data['Seniority'])

# %%
prospects_firmo_data['Contact_City']= prospects_firmo_data['Contact_City'].fillna(prospects_firmo_data['Contact City'])

# %%
prospects_firmo_data['Contact_State']= prospects_firmo_data['Contact_State'].fillna(prospects_firmo_data['Contact State'])

# %%
prospects_firmo_data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
prospects_firmo_data.shape
# Out:
# (157517, 34)

# %%
prospects_firmo_data['derived_mail']=prospects_firmo_data['Email']

# %%
clicked_prospects_data=clicked_prospects_emails.merge(prospects_firmo_data,on='derived_mail',how='left')

# %%
clicked_prospects_data.shape
# Out:
# (9521, 36)

# %% [markdown]
# ## NOTE WE HAVE TO REMOVE THOSE PROSPECTS WHICH ARE CLICKED THE EMAIL BUT THEIR FIRMOGRAPHIC DATA IS NOT AVAILABLE

# %%
prospect_engagements.shape
# Out:
# (5663590, 30)

# %%
prospect_engagements.drop(columns=['Unnamed: 0'],inplace=True)

# %%
merged_data=prospect_engagements.merge(clicked_prospects_emails[['derived_mail','email_clicked_time']],on='derived_mail',how='inner')

# %%
filtered_merged_data=merged_data[(merged_data['status_time_utc']<=merged_data['email_clicked_time'])]

# %%
filtered_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263816 entries, 0 to 559526
# Data columns (total 30 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   FirstName           263816 non-null  object
#  1   CompanyName         263816 non-null  object
#  2   mail                263816 non-null  object
#  3   Email               263816 non-null  object
#  4   CTA                 263816 non-null  object
#  5   Domain              263816 non-null  object
#  6   ID                  263816 non-null  object
#  7   source              263816 non-null  object
#  8   date                263816 non-null  object
#  9   raw_status          263816 non-null  object
#  10  status              263815 non-null  object
#  11  status_time         263816 non-null  object
#  12  reason              0 non-null       object
#  13  status_time_utc     263816 non-null  datetime64[ns, UTC]
#  14  derived_mail        263816 non-null  object
#  15  derived_email       263816 non-null  object
#  16  is_email_sent       263816 non-null  int64
#  17  is_email_clicked    263816 non-null  int64
#  18  is_email_opened     263816 non-null  int64
#  19  is_responded        263816 non-null  int64
#  20  is_bounced          263816 non-null  int64
#  21  is_unsubscribed     263816 non-null  int64
#  22  is_mail_not_sent    263816 non-null  int64
#  23  is_scheduled        263816 non-null  int64
#  24  2_weeks_ago         263816 non-null  object
#  25  4_weeks_ago         263816 non-null  object
#  26  8_weeks_ago         263816 non-null  object
#  27  12_weeks_ago        263816 non-null  object
#  28  day_of_week         263816 non-null  object
#  29  email_clicked_time  263816 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](2), int64(8), object(20)
# memory usage: 62.4+ MB

# %%
# filtered_merged_data[['derived_mail','status_time_utc','email_clicked_time']]

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# ## Total Emails Sent

# %%
total_emails_sent=filtered_merged_data.groupby('derived_mail')['is_email_sent'].sum().reset_index(name='total_emails_sent')

# %%
total_emails_sent
# Out:
#                            derived_mail  total_emails_sent
# 0                       a-holley@ti.com                 23
# 1                       a-smith3@ti.com                 17
# 2                   a.danielson@aps.com                 12
# 3                 a.freitas@samsung.com                 57
# 4                   a.khani@samsung.com                 57
# ...                                 ...                ...
# 9516                    zluo@amazon.com                  6
# 9517             zoe.taylor@walmart.com                 41
# 9518       zsolt.gyurko@flextronics.com                 14
# 9519  zulfiqar.haider@cityofchicago.org                 27
# 9520           zwadie.castro@jacobs.com                 57
#
# [9521 rows x 2 columns]

# %% [markdown]
# ## Total Emails Clicked

# %%
total_emails_clicked=filtered_merged_data.groupby('derived_mail')['is_email_clicked'].sum().reset_index(name='total_emails_clicked')

# %%
total_emails_clicked.sort_values(by='total_emails_clicked',ascending=False)
# Out:
#                         derived_mail  total_emails_clicked
# 9393             wwashington@rbi.com                     4
# 6346    michael_freeman@na.honda.com                     4
# 1225         brock.nelson@jacobs.com                     4
# 9137      valerie.larcinese@ch2m.com                     4
# 7685   ron.thurlow@nexteraenergy.com                     4
# ...                              ...                   ...
# 3642    james.lecroy@duke-energy.com                     1
# 3640  james.karner@cityofchicago.org                     1
# 3639         james.kaczur@jacobs.com                     1
# 3638          james.johns@jacobs.com                     1
# 9520        zwadie.castro@jacobs.com                     1
#
# [9521 rows x 2 columns]

# %% [markdown]
# ## Total Emails Opened

# %%
total_emails_opened=filtered_merged_data.groupby('derived_mail')['is_email_opened'].sum().reset_index(name='total_emails_opened')

# %%
total_emails_opened.sort_values(by='total_emails_opened',ascending=False)
# Out:
#                           derived_mail  total_emails_opened
# 4596               joshua.ou@apple.com                   37
# 1487          charla_stewart@apple.com                   27
# 7250         rahul.sangam@nexsales.com                   26
# 6860               o.temiz@samsung.com                   21
# 469               andrew.jones@atl.com                   20
# ...                                ...                  ...
# 3735  jason.berthiaume@duke-energy.com                    1
# 3734        jason.bernagros@jacobs.com                    1
# 3732   jason.andrews@nexteraenergy.com                    1
# 3731             jasmine_chen@amat.com                    1
# 9520          zwadie.castro@jacobs.com                    1
#
# [9521 rows x 2 columns]

# %% [markdown]
# ## Total Emails Unsubscribed

# %%
total_emails_unsubscribed=filtered_merged_data.groupby('derived_mail')['is_unsubscribed'].sum().reset_index(name='total_emails_unsubscribed')

# %%
total_emails_unsubscribed
# Out:
#                            derived_mail  total_emails_unsubscribed
# 0                       a-holley@ti.com                          0
# 1                       a-smith3@ti.com                          0
# 2                   a.danielson@aps.com                          0
# 3                 a.freitas@samsung.com                          0
# 4                   a.khani@samsung.com                          0
# ...                                 ...                        ...
# 9516                    zluo@amazon.com                          0
# 9517             zoe.taylor@walmart.com                          0
# 9518       zsolt.gyurko@flextronics.com                          0
# 9519  zulfiqar.haider@cityofchicago.org                          0
# 9520           zwadie.castro@jacobs.com                          0
#
# [9521 rows x 2 columns]

# %% [markdown]
# ## Total Emails Bounced

# %%
total_emails_bounced=filtered_merged_data.groupby('derived_mail')['is_bounced'].sum().reset_index(name='total_emails_bounced')

# %%
total_emails_bounced
# Out:
#                            derived_mail  total_emails_bounced
# 0                       a-holley@ti.com                     0
# 1                       a-smith3@ti.com                     0
# 2                   a.danielson@aps.com                     0
# 3                 a.freitas@samsung.com                     0
# 4                   a.khani@samsung.com                     0
# ...                                 ...                   ...
# 9516                    zluo@amazon.com                     0
# 9517             zoe.taylor@walmart.com                     0
# 9518       zsolt.gyurko@flextronics.com                     0
# 9519  zulfiqar.haider@cityofchicago.org                     0
# 9520           zwadie.castro@jacobs.com                     0
#
# [9521 rows x 2 columns]

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_sent,on='derived_mail',how='left')

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_opened,on='derived_mail',how='left')

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_clicked,on='derived_mail',how='left')

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_bounced,on='derived_mail',how='left')

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_unsubscribed,on='derived_mail',how='left')

# %%
clicked_prospects_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9521 entries, 0 to 9520
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   derived_mail               9521 non-null   object
#  1   email_clicked_time         9521 non-null   datetime64[ns, UTC]
#  2   status                     9521 non-null   object
#  3   Company Name               9466 non-null   object
#  4   First Name                 9466 non-null   object
#  5   Middle Name                287 non-null    object
#  6   Last Name                  9466 non-null   object
#  7   Title                      9466 non-null   object
#  8   Level                      8141 non-null   object
#  9   Seniority                  152 non-null    object
#  10  Department                 8141 non-null   object
#  11  Email ID                   8037 non-null   object
#  12  Email 1                    1429 non-null   object
#  13  Contact_City               8540 non-null   object
#  14  Contact_State              7506 non-null   object
#  15  Contact City               1344 non-null   object
#  16  Contact State              1141 non-null   object
#  17  Contact Country            152 non-null    object
#  18  Country                    8037 non-null   object
#  19  Website                    9465 non-null   object
#  20  Company City               9292 non-null   object
#  21  Company State              8620 non-null   object
#  22  Company Country            9424 non-null   object
#  23  Industry                   8037 non-null   object
#  24  Sub Industry               19 non-null     object
#  25  Revenue                    7903 non-null   object
#  26  Revenue Range              6227 non-null   object
#  27  EMP Range                  7995 non-null   object
#  28  Company Annual Revenue     1429 non-null   object
#  29  Company Industry           1429 non-null   object
#  30  Company Staff Count Range  1383 non-null   object
#  31  Company Staff Count        1429 non-null   object
#  32  Contact Linkedin URL       6549 non-null   object
#  33  Contact LI Profile URL     1406 non-null   object
#  34  source                     9466 non-null   object
#  35  Email                      9466 non-null   object
#  36  total_emails_sent          9521 non-null   int64
#  37  total_emails_opened        9521 non-null   int64
#  38  total_emails_clicked       9521 non-null   int64
#  39  total_emails_bounced       9521 non-null   int64
#  40  total_emails_unsubscribed  9521 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(5), object(35)
# memory usage: 3.0+ MB

# %% [markdown]
# ## Average Time Between Emails

# %%
filtered_merged_data['status_time_utc'] = pd.to_datetime(filtered_merged_data['status_time_utc'], utc=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\699942996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_data['status_time_utc'] = pd.to_datetime(filtered_merged_data['status_time_utc'], utc=True)

# %%
filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\4170549331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],inplace=True)

# %%
sent_emails=filtered_merged_data[filtered_merged_data['is_email_sent']==1]

# %%
sent_emails['time_gap']=sent_emails.groupby('derived_mail')['status_time_utc'].diff().dt.days
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\1506379369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_emails['time_gap']=sent_emails.groupby('derived_mail')['status_time_utc'].diff().dt.days

# %%
avg_time_between_emails=sent_emails.groupby('derived_mail')['time_gap'].mean().reset_index().rename(columns={'time_gap': 'avg_time_between_emails'})

# %%
avg_time_between_emails
# Out:
#                            derived_mail  avg_time_between_emails
# 0                       a-holley@ti.com                 1.318182
# 1                       a-smith3@ti.com                 0.937500
# 2                   a.danielson@aps.com                 1.181818
# 3                 a.freitas@samsung.com                 0.857143
# 4                   a.khani@samsung.com                 0.857143
# ...                                 ...                      ...
# 9516                    zluo@amazon.com                 7.200000
# 9517             zoe.taylor@walmart.com                 0.450000
# 9518       zsolt.gyurko@flextronics.com                 0.846154
# 9519  zulfiqar.haider@cityofchicago.org                 2.192308
# 9520           zwadie.castro@jacobs.com                 1.625000
#
# [9521 rows x 2 columns]

# %%
clicked_prospects_data=clicked_prospects_data.merge(avg_time_between_emails,on='derived_mail',how='left')

# %% [markdown]
# ## Average Time Between Email Opened

# %%
opened_emails=filtered_merged_data[filtered_merged_data['is_email_opened']==1]

# %%
opened_emails.shape
# Out:
# (13729, 30)

# %%
opened_emails['time_gap']=opened_emails.groupby('derived_mail')['status_time_utc'].diff().dt.days
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\3877662092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opened_emails['time_gap']=opened_emails.groupby('derived_mail')['status_time_utc'].diff().dt.days

# %%
avg_time_between_emails_opened=opened_emails.groupby('derived_mail')['time_gap'].mean().reset_index().rename(columns={'time_gap': 'avg_time_between_emails_opened'})

# %%
avg_time_between_emails_opened
# Out:
#                            derived_mail  avg_time_between_emails_opened
# 0                       a-holley@ti.com                             NaN
# 1                       a-smith3@ti.com                             NaN
# 2                   a.danielson@aps.com                             NaN
# 3                 a.freitas@samsung.com                             NaN
# 4                   a.khani@samsung.com                             NaN
# ...                                 ...                             ...
# 9516                    zluo@amazon.com                             NaN
# 9517             zoe.taylor@walmart.com                             NaN
# 9518       zsolt.gyurko@flextronics.com                             NaN
# 9519  zulfiqar.haider@cityofchicago.org                             NaN
# 9520           zwadie.castro@jacobs.com                             NaN
#
# [9521 rows x 2 columns]

# %%
clicked_prospects_data=clicked_prospects_data.merge(avg_time_between_emails_opened,on='derived_mail',how='left')

# %% [markdown]
# ## Days Since Last Email Opened

# %%
filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],ascending=True,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\3285368224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],ascending=True,inplace=True)

# %%
prospects_last_email_opened_data=filtered_merged_data[filtered_merged_data['is_email_opened']==1].groupby('derived_mail')['status_time_utc'].max().reset_index(name='last_email_opened_date')

# %%
prospects_last_email_opened_data[prospects_last_email_opened_data['derived_mail']=='joshua.ou@apple.com']
# Out:
#              derived_mail    last_email_opened_date
# 4596  joshua.ou@apple.com 2025-01-17 14:31:00+00:00

# %%
clicked_prospects_data=clicked_prospects_data.merge(prospects_last_email_opened_data,on='derived_mail',how='left')

# %%
clicked_prospects_data['days_since_last_email_opened']=(clicked_prospects_data['email_clicked_time']-clicked_prospects_data['last_email_opened_date']).dt.days

# %%
clicked_prospects_data['days_since_last_email_opened'].value_counts()
# Out:
# days_since_last_email_opened
# 0    9521
# Name: count, dtype: int64

# %%
clicked_prospects_emails[clicked_prospects_emails['derived_mail']=='zurielsuarez@dswinc.com']
# Out:
# Empty DataFrame
# Columns: [derived_mail, email_clicked_time, status]
# Index: []

# %%
filtered_merged_data['status'].value_counts()
# Out:
# status
# EMAIL_SENT        247093
# EMAIL_CLICKED      12108
# EMAIL_NOT_SENT      2957
# EMAIL_OPENED        1617
# UNSUBSCRIBED          35
# RESPONDED              4
# BOUNCED                1
# Name: count, dtype: int64

# %%
filtered_merged_data[filtered_merged_data['status']=='EMAIL_OPENED']['derived_mail'].value_counts()
# Out:
# derived_mail
# joshua.ou@apple.com               36
# charla_stewart@apple.com          26
# rahul.sangam@nexsales.com         23
# o.temiz@samsung.com               20
# andrew.jones@atl.com              19
#                                   ..
# daniel.caudell@duke-energy.com     1
# daniel.valdez@oncor.com            1
# martin.garvin@duke-energy.com      1
# marsha.anderson@oncor.com          1
# justin.brucke@duke-energy.com      1
# Name: count, Length: 641, dtype: int64

# %%
filtered_merged_data[filtered_merged_data['derived_mail']=='joshua.ou@apple.com']
# Out:
#        FirstName CompanyName                 mail  \
# 271633    Joshua  Apple Inc.  joshua.ou@apple.com
# 271634    Joshua  Apple Inc.  joshua.ou@apple.com
# 271635    Joshua  Apple Inc.  joshua.ou@apple.com
# 271636    Joshua  Apple Inc.  joshua.ou@apple.com
# 271637    Joshua  Apple Inc.  joshua.ou@apple.com
# 271638    Joshua  Apple Inc.  joshua.ou@apple.com
# 271639    Joshua  Apple Inc.  joshua.ou@apple.com
# 271640    Joshua  Apple Inc.  joshua.ou@apple.com
# 271641    Joshua  Apple Inc.  joshua.ou@apple.com
# 271642    Joshua  Apple Inc.  joshua.ou@apple.com
# 271643    Joshua  Apple Inc.  joshua.ou@apple.com
# 271644    Joshua  Apple Inc.  joshua.ou@apple.com
# 271645    Joshua  Apple Inc.  joshua.ou@apple.com
# 271646    Joshua  Apple Inc.  joshua.ou@apple.com
# 271662          28-Dec-2024
# 271663          30-Dec-2024
# 271664  2024-12-31 00:00:00
# 271665          31-Dec-2024
# 271666  2025-01-02 00:00:00
# 271667  2025-01-03 00:00:00
# 271668  2025-01-04 00:00:00
# 271669  2025-01-06 00:00:00
# 271670  2025-01-07 00:00:00
# 271671  2025-01-08 00:00:00
# 271672  2025-01-09 00:00:00
# 271673  2025-01-10 00:00:00
# 271674  2025-01-11 00:00:00
# 271675          13-Jan-2025
# 271676          14-Jan-2025
# 271677          15-Jan-2025
# 271678          16-Jan-2025
# 271679          17-Jan-2025
#
#                                                raw_status         status  \
# 271633             EMAIL_SENT # 12/10/2024 - 05:13 PM UTC     EMAIL_SENT
# 271634             EMAIL_SENT # 12/11/2024 - 05:48 PM UTC     EMAIL_SENT
# 271635             EMAIL_SENT # 12/12/2024 - 05:45 PM UTC     EMAIL_SENT
# 271636             EMAIL_SENT # 12/12/2024 - 05:45 PM UTC     EMAIL_SENT
# 271637             EMAIL_SENT # 12/13/2024 - 04:56 PM UTC     EMAIL_SENT
# 271638             EMAIL_SENT # 12/13/2024 - 04:56 PM UTC     EMAIL_SENT
# 271639             EMAIL_SENT # 12/14/2024 - 02:06 PM UTC     EMAIL_SENT
# 271640             EMAIL_SENT # 12/14/2024 - 02:06 PM UTC     EMAIL_SENT
# 271641   EMAIL_OPENED # Opened: 12/17/2024 - 07:44 AM UTC   EMAIL_OPENED
# 271642   EMAIL_OPENED # Opened: 12/17/2024 - 07:44 AM UTC   EMAIL_OPENED
# 271643   EMAIL_OPENED # Opened: 12/17/2024 - 03:42 PM UTC   EMAIL_OPENED
# 271644   EMAIL_OPENED # Opened: 12/17/2024 - 03:42 PM UTC   EMAIL_OPENED
# 271645   EMAIL_OPENED # Opened: 12/18/2024 - 02:08 PM UTC   EMAIL_OPENED
# 271646   EMAIL_OPENED # Opened: 12/18/2024 - 02:08 PM UTC   EMAIL_OPENED
# 271647   EMAIL_OPENED # Opened: 12/20/2024 - 06:42 AM UTC   EMAIL_OPENED
# 271648   EMAIL_OPENED # Opened: 12/20/2024 - 06:42 AM UTC   EMAIL_OPENED
# 271649   EMAIL_OPENED # Opened: 12/20/2024 - 02:14 PM UTC   EMAIL_OPENED
# 271650   EMAIL_OPENED # Opened: 12/20/2024 - 02:14 PM UTC   EMAIL_OPENED
# 271651   EMAIL_OPENED # Opened: 12/21/2024 - 04:37 PM UTC   EMAIL_OPENED
# 271652   EMAIL_OPENED # Opened: 12/21/2024 - 04:37 PM UTC   EMAIL_OPENED
# 271653   EMAIL_OPENED # Opened: 12/21/2024 - 04:37 PM UTC   EMAIL_OPENED
# 271654   EMAIL_OPENED # Opened: 12/21/2024 - 04:37 PM UTC   EMAIL_OPENED
# 271655             EMAIL_SENT # 12/25/2024 - 01:40 PM UTC     EMAIL_SENT
# 271656   EMAIL_OPENED # Opened: 12/25/2024 - 08:46 PM UTC   EMAIL_OPENED
# 271657   EMAIL_OPENED # Opened: 12/25/2024 - 08:46 PM UTC   EMAIL_OPENED
# 271658   EMAIL_OPENED # Opened: 12/27/2024 - 05:47 PM UTC   EMAIL_OPENED
# 271659   EMAIL_OPENED # Opened: 12/27/2024 - 05:47 PM UTC   EMAIL_OPENED
# 271660   EMAIL_OPENED # Opened: 12/28/2024 - 05:12 PM UTC   EMAIL_OPENED
# 271661   EMAIL_OPENED # Opened: 12/28/2024 - 05:12 PM UTC   EMAIL_OPENED
# 271662   EMAIL_OPENED # Opened: 12/28/2024 - 05:12 PM UTC   EMAIL_OPENED
# 271663   EMAIL_OPENED # Opened: 12/28/2024 - 05:12 PM UTC   EMAIL_OPENED
# 271664   EMAIL_OPENED # Opened: 01/01/2025 - 11:37 PM UTC   EMAIL_OPENED
# 271665   EMAIL_OPENED # Opened: 01/01/2025 - 11:37 PM UTC   EMAIL_OPENED
# 271666             EMAIL_SENT # 01/02/2025 - 12:44 PM UTC     EMAIL_SENT
# 271667   EMAIL_OPENED # Opened: 01/04/2025 - 12:39 AM UTC   EMAIL_OPENED
# 271668   EMAIL_OPENED # Opened: 01/04/2025 - 12:39 AM UTC   EMAIL_OPENED
# 271669   EMAIL_OPENED # Opened: 01/06/2025 - 11:32 PM UTC   EMAIL_OPENED
# 271670   EMAIL_OPENED # Opened: 01/07/2025 - 05:09 PM UTC   EMAIL_OPENED
# 271671   EMAIL_OPENED # Opened: 01/07/2025 - 05:09 PM UTC   EMAIL_OPENED
# 271672   EMAIL_OPENED # Opened: 01/09/2025 - 04:54 PM UTC   EMAIL_OPENED
# 271673   EMAIL_OPENED # Opened: 01/09/2025 - 04:54 PM UTC   EMAIL_OPENED
# 271674   EMAIL_OPENED # Opened: 01/11/2025 - 11:18 PM UTC   EMAIL_OPENED
# 271675   EMAIL_OPENED # Opened: 01/14/2025 - 09:56 AM UTC   EMAIL_OPENED
# 271676   EMAIL_OPENED # Opened: 01/14/2025 - 09:56 AM UTC   EMAIL_OPENED
# 271677   EMAIL_OPENED # Opened: 01/16/2025 - 02:00 AM UTC   EMAIL_OPENED
# 271678   EMAIL_OPENED # Opened: 01/16/2025 - 02:00 AM UTC   EMAIL_OPENED
# 271679  EMAIL_CLICKED # Clicked: 01/17/2025 - 02:31 PM...  EMAIL_CLICKED
#
#                       status_time reason           status_time_utc  \
# 271633  12/10/2024 - 05:13 PM UTC    NaN 2024-12-10 17:13:00+00:00
# 271634  12/11/2024 - 05:48 PM UTC    NaN 2024-12-11 17:48:00+00:00
# 271635  12/12/2024 - 05:45 PM UTC    NaN 2024-12-12 17:45:00+00:00
# 271636  12/12/2024 - 05:45 PM UTC    NaN 2024-12-12 17:45:00+00:00
# 271637  12/13/2024 - 04:56 PM UTC    NaN 2024-12-13 16:56:00+00:00
# 271638  12/13/2024 - 04:56 PM UTC    NaN 2024-12-13 16:56:00+00:00
# 271639  12/14/2024 - 02:06 PM UTC    NaN 2024-12-14 14:06:00+00:00
# 271640  12/14/2024 - 02:06 PM UTC    NaN 2024-12-14 14:06:00+00:00
# 271641  12/17/2024 - 07:44 AM UTC    NaN 2024-12-17 07:44:00+00:00
# 271642  12/17/2024 - 07:44 AM UTC    NaN 2024-12-17 07:44:00+00:00
# 271664 2025-01-17 14:31:00+00:00
# 271665 2025-01-17 14:31:00+00:00
# 271666 2025-01-17 14:31:00+00:00
# 271667 2025-01-17 14:31:00+00:00
# 271668 2025-01-17 14:31:00+00:00
# 271669 2025-01-17 14:31:00+00:00
# 271670 2025-01-17 14:31:00+00:00
# 271671 2025-01-17 14:31:00+00:00
# 271672 2025-01-17 14:31:00+00:00
# 271673 2025-01-17 14:31:00+00:00
# 271674 2025-01-17 14:31:00+00:00
# 271675 2025-01-17 14:31:00+00:00
# 271676 2025-01-17 14:31:00+00:00
# 271677 2025-01-17 14:31:00+00:00
# 271678 2025-01-17 14:31:00+00:00
# 271679 2025-01-17 14:31:00+00:00

# %%
clicked_prospects_emails[clicked_prospects_emails['derived_mail']=='joshua.ou@apple.com']
# Out:
#              derived_mail        email_clicked_time         status
# 4596  joshua.ou@apple.com 2025-01-17 14:31:00+00:00  EMAIL_CLICKED

# %% [markdown]
# ## Total Emails Sent On Week-Ends (Saturday - Sunday)

# %%
filtered_merged_data['day_of_week']=filtered_merged_data["status_time_utc"].dt.day_name()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\1466573649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_data['day_of_week']=filtered_merged_data["status_time_utc"].dt.day_name()

# %%
sent_emails=filtered_merged_data[filtered_merged_data['is_email_sent']==1]

# %%
sent_emails['day_of_week'].value_counts()
# Out:
# day_of_week
# Thursday     46102
# Monday       44565
# Tuesday      44317
# Friday       43415
# Wednesday    43412
# Saturday     38635
# Sunday         411
# Name: count, dtype: int64

# %%
total_emails_sent_week_ends=sent_emails[sent_emails['day_of_week'].isin(['Saturday','Sunday'])].groupby('derived_mail').size().reset_index(name='total_emails_sent_week_ends')

# %%
total_emails_sent_week_ends
# Out:
#                            derived_mail  total_emails_sent_week_ends
# 0                       a-holley@ti.com                            5
# 1                       a-smith3@ti.com                            2
# 2                   a.danielson@aps.com                            2
# 3                 a.freitas@samsung.com                            9
# 4                   a.khani@samsung.com                            9
# ...                                 ...                          ...
# 8301              zim.zaman@samsung.com                            7
# 8302             zoe.taylor@walmart.com                            7
# 8303       zsolt.gyurko@flextronics.com                            2
# 8304  zulfiqar.haider@cityofchicago.org                            3
# 8305           zwadie.castro@jacobs.com                            9
#
# [8306 rows x 2 columns]

# %%
clicked_prospects_data=clicked_prospects_data.merge(total_emails_sent_week_ends,on='derived_mail',how='left')

# %% [markdown]
# ## Last Email Status

# %%
filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1300\4170549331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_merged_data.sort_values(by=['derived_mail','status_time_utc'],inplace=True)

# %%
prospect_last_email_status=filtered_merged_data[filtered_merged_data['status'].isin(['EMAIL_SENT',
       'EMAIL_OPENED', 'EMAIL_CLICKED', 'UNSUBSCRIBED', 'RESPONDED'])].groupby('derived_mail')['status'].last().reset_index(name='last_email_status')

# %%
prospect_last_email_status
# Out:
#                            derived_mail last_email_status
# 0                       a-holley@ti.com     EMAIL_CLICKED
# 1                       a-smith3@ti.com     EMAIL_CLICKED
# 2                   a.danielson@aps.com     EMAIL_CLICKED
# 3                 a.freitas@samsung.com     EMAIL_CLICKED
# 4                   a.khani@samsung.com     EMAIL_CLICKED
# ...                                 ...               ...
# 9516                    zluo@amazon.com     EMAIL_CLICKED
# 9517             zoe.taylor@walmart.com     EMAIL_CLICKED
# 9518       zsolt.gyurko@flextronics.com     EMAIL_CLICKED
# 9519  zulfiqar.haider@cityofchicago.org     EMAIL_CLICKED
# 9520           zwadie.castro@jacobs.com     EMAIL_CLICKED
#
# [9521 rows x 2 columns]

# %%
prospect_last_email_status['last_email_status']=prospect_last_email_status['last_email_status'].replace('RESPONDED','EMAIL_OPENED')

# %%
clicked_prospects_data=clicked_prospects_data.merge(prospect_last_email_status,on='derived_mail',how='left')

# %% [markdown]
# ## Has Ever Opened Email

# %%
clicked_prospects_data['has_ever_opened_email']=clicked_prospects_data['total_emails_opened'].apply(lambda x : 1 if x>0 else 0)

# %%
clicked_prospects_data.to_csv('../datasets/clicked_data/clicked_prospects.csv')

# %%
clicked_prospects_data.shape
# Out:
# (9521, 48)

# %%
clicked_prospects_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9521 entries, 0 to 9520
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   derived_mail                    9521 non-null   object
#  1   email_clicked_time              9521 non-null   datetime64[ns, UTC]
#  2   status                          9521 non-null   object
#  3   Company Name                    9466 non-null   object
#  4   First Name                      9466 non-null   object
#  5   Middle Name                     287 non-null    object
#  6   Last Name                       9466 non-null   object
#  7   Title                           9466 non-null   object
#  8   Level                           8141 non-null   object
#  9   Seniority                       152 non-null    object
#  10  Department                      8141 non-null   object
#  11  Email ID                        8037 non-null   object
#  12  Email 1                         1429 non-null   object
#  13  Contact_City                    8540 non-null   object
#  14  Contact_State                   7506 non-null   object
#  15  Contact City                    1344 non-null   object
#  16  Contact State                   1141 non-null   object
#  17  Contact Country                 152 non-null    object
#  18  Country                         8037 non-null   object
#  19  Website                         9465 non-null   object
#  20  Company City                    9292 non-null   object
#  21  Company State                   8620 non-null   object
#  22  Company Country                 9424 non-null   object
#  23  Industry                        8037 non-null   object
#  24  Sub Industry                    19 non-null     object
#  25  Revenue                         7903 non-null   object
#  26  Revenue Range                   6227 non-null   object
#  27  EMP Range                       7995 non-null   object
#  28  Company Annual Revenue          1429 non-null   object
#  29  Company Industry                1429 non-null   object
#  30  Company Staff Count Range       1383 non-null   object
#  31  Company Staff Count             1429 non-null   object
#  32  Contact Linkedin URL            6549 non-null   object
#  33  Contact LI Profile URL          1406 non-null   object
#  34  source                          9466 non-null   object
#  35  Email                           9466 non-null   object
#  36  total_emails_sent               9521 non-null   int64
#  37  total_emails_opened             9521 non-null   int64
#  38  total_emails_clicked            9521 non-null   int64
#  39  total_emails_bounced            9521 non-null   int64
#  40  total_emails_unsubscribed       9521 non-null   int64
#  41  avg_time_between_emails         9249 non-null   float64
#  42  avg_time_between_emails_opened  2812 non-null   float64
#  43  last_email_opened_date          9521 non-null   datetime64[ns, UTC]
#  44  days_since_last_email_opened    9521 non-null   int64
#  45  total_emails_sent_week_ends     8306 non-null   float64
#  46  last_email_status               9521 non-null   object
#  47  has_ever_opened_email           9521 non-null   int64
# dtypes: datetime64[ns, UTC](2), float64(3), int64(7), object(36)
# memory usage: 3.5+ MB
