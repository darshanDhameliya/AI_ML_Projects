# %%
import pandas as pd

# %%
acc_df = pd.read_csv('/home/darshan/Documents/Schneider Electric Data/6sense Ads/acc_6sence_ads.csv')
acc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906 entries, 0 to 905
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             906 non-null    int64
#  1   Campaign ID            906 non-null    int64
#  2   6sense Company Name    906 non-null    object
#  3   6sense Country         906 non-null    object
#  4   6sense Domain          902 non-null    object
#  5   Impressions            906 non-null    int64
#  6   Clicks                 906 non-null    int64
#  7   Spend                  906 non-null    float64
#  8   Website Engagement     906 non-null    object
#  9   Latest Impression      906 non-null    object
#  10  Influenced Form Fills  906 non-null    int64
#  11  Video Error            906 non-null    int64
#  12  Video Start            906 non-null    int64
#  13  Video Skip             906 non-null    int64
# ...

# %%
acc_df.head()
# Out:
#    Unnamed: 0  Campaign ID      6sense Company Name  6sense Country  \
# 0           0       227898              Xcel Energy   United States
# 1           1       227898        UK Power Networks  United Kingdom
# 2           2       227898    Tucson Electric Power   United States
# 3           3       227898  Tacoma Public Utilities   United States
# 4           4       227898         Southern Company   United States
#
#            6sense Domain  Impressions  Clicks  Spend Website Engagement  \
# 0         xcelenergy.com          481       0   3.38                New
# 1  ukpowernetworks.co.uk         1163       0   8.17                  -
# 2                tep.com          156       0   1.10                  -
# 3              mytpu.org            4       0   0.03                  -
# 4    southerncompany.com          772       0   5.42                  -
#
#   Latest Impression  ...  Video 25% Complete  Video 50% Complete  \
# ...

# %%
acc_df.duplicated(subset=['6sense Domain'], keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 901     True
# 902     True
# 903     True
# 904     True
# 905     True
# Length: 906, dtype: bool

# %%
acc_df['6sense Domain'].value_counts()
# Out:
# 6sense Domain
# dominos.com           5
# coop.co.uk            4
# next.co.uk            4
# johnlewis.com         4
# sainsburys.co.uk      3
#                      ..
# focusedumatics.com    1
# firstam.com           1
# fidelity.com          1
# ferrovial.com         1
# thehausergroup.com    1
# Name: count, Length: 791, dtype: int64

# %%
acc_df[acc_df['6sense Domain'] == 'dominos.com']
# Out:
#      Unnamed: 0  Campaign ID 6sense Company Name  6sense Country  \
# 401         401       230257      Domino's Pizza   United States
# 438         438       227665      Domino's Pizza   United States
# 470         470       227697      Domino's Pizza   United States
# 855         855       225723      Domino's Pizza  United Kingdom
# 891         891       230478      Domino's Pizza  United Kingdom
#
#     6sense Domain  Impressions  Clicks  Spend Website Engagement  \
# 401   dominos.com          176       0   1.84                  -
# 438   dominos.com          384       0   1.64                New
# 470   dominos.com          158       1   1.67                New
# 855   dominos.com          568       0   2.93                  -
# 891   dominos.com          405       1   3.66                  -
#
#     Latest Impression  ...  Video 25% Complete  Video 50% Complete  \
# 401        2024-11-25  ...                   0                   0
# ...
